# %% [markdown]
# <a href="https://colab.research.google.com/github/afifask1316-web/elitech-data-analytics-internship/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
from google.colab import files
uploaded = files.upload()
